# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
example_df = pd.read_csv(r'data\Raw eeg 2\S7_eeg_Calibration.csv')

# %%
example_df.head()

# %%
print(np.unique(example_df["class"]))
print(np.unique(example_df["trial"]))
print(len(example_df["TimeStamp"]))

# %%
plt.plot(example_df["CP1"][:7000])
plt.show()
